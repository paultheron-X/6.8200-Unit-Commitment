# %%
from rl4uc.environment import make_env, make_env_from_json

env = make_env(num_gen = 15)
# Out:
# /Users/paultheron/opt/anaconda3/envs/sensorimotor/lib/python3.9/site-packages/gym/envs/registration.py:307: DeprecationWarning: The package name gym_minigrid has been deprecated in favor of minigrid. Please uninstall gym_minigrid and install minigrid with `pip install minigrid`. Future releases will be maintained under the new package name minigrid.
#   fn()

# %%
obs_init = env.reset()
obs_init
# Out:
# {'status': array([-16,  16, -16, -16,  10,  10, -10,  10,  12, -12,   6,  -6,   2,
#           2,  -2]),
#  'demand_forecast': array([1271.16528873, 1244.88272291, 1241.18401745, 1254.89098473,
#         1268.72849455, 1259.89511564, 1250.67010909, 1246.14463418,
#         1230.17492945, 1223.125632  , 1229.17410327, 1251.58390691,
#         1311.676992  , 1358.06310982, 1451.96671418, 1518.71746909,
#         1608.05208436, 1629.67863273, 1642.38477382, 1634.59573527,
#         1617.58169018, 1596.73839709, 1576.11267491, 1574.02399418,
#         1574.67670691, 1577.59215709, 1582.03060364, 1576.46078836,
#         1589.38450036, 1595.998656  , 1605.13663418, 1617.62520436,
#         1662.22724073, 1721.14544291, 1793.37898473, 1852.47124364,
#         1897.94356364, 1889.50181236, 1856.34400582, 1803.90941673,
#         1752.040512  , 1706.13305018, 1646.21402182, 1586.55607855,
#         1534.46960291, 1477.42251055, 1422.63815564, 1374.07632873]),
# ...

# %%
len(obs_init['demand_forecast'])
# Out:
# 48

# %%
env.action_space.sample()
# Out:
# array([0, 1, 0, 1, 1, 0, 0, 1, 1, 1, 0, 1, 0, 0, 1], dtype=int16)

# %%
action = [0 for _ in range(10)]
obs = env.step(action)
obs
# Out:
# ({'status': array([-25,  -9, -19,  -9,  -9, -15, -15,  -9, -11,  -9]),
#   'demand_forecast': array([ 808.28076218,  791.22320291,  788.46730473,  786.90079418,
#           784.28994327,  774.04960582,  773.41139782,  773.00526545,
#           772.94724655,  778.83616582,  789.85975855,  803.11707927,
#           836.82606545,  885.21383564,  950.34006109,  985.67357673,
#          1013.72571927, 1018.33822255, 1016.88774982, 1005.77712873,
#           997.36438691,  986.31178473,  985.64456727,  984.28112291,
#           983.09173527,  973.17050182,  956.43204655,  945.292416  ,
#           943.75491491,  942.71057455,  948.71553164,  950.48510836,
#           959.53605818,  981.989376  ,  997.91556655, 1006.09623273,
#          1006.73444073, 1012.304256  , 1006.99552582, 1001.83184291,
#           996.75518836, 1005.22594909,  993.24504436,  958.98487855,
#           922.51999418,  882.98010764,  838.01545309,  802.59490909]),
# ...
